# %% [markdown]
# # V1 — Chainlink v11 Weekend Bias (H8)
#
# **Gate:** if pooled $E[e_T] \approx 0$ with tight SE and 95% CI hit rate ~95%, Chainlink's weekend aggregation is unbiased → thesis is weak, pivot. If pooled bias is significant at 5% with non-trivial effect size (>10 bps), greenlight Phase 1.
#
# **Data:**
# - Chainlink v11 weekend prices reconstructed from Solana on-chain (Helius RPC → Kamino → Chainlink Verifier tx decoding).
# - NYSE Friday close / Monday open via yfinance for 8 xStock underlyings.
#
# **Output:** one chart + one pooled t-stat + per-ticker table → `reports/v1_chainlink_bias.md`.

# %%
from soothsayer.config import REPORTS, DATA_RAW
from soothsayer.universe import CORE_XSTOCKS

# TODO: implement once src/soothsayer/sources/chainlink_solana.py and yfinance_eod.py exist
