# %% [markdown]
# # V3 — Kraken Perp Funding Signal (H9)
#
# **Gate:** in the augmented regression $g_T = \alpha + X\beta + \delta f^T_{\text{Sun-evening}} + \varepsilon_T$, is $\delta$ significant at 5% and $\Delta R^2 > 2\%$? If yes, add funding to MVP ingest signal set. If no, keep as backup, not a headline input.
#
# **Data:**
# - Kraken public REST — 10 xStock perp funding series since Feb 24 2026.
# - yfinance — Friday close / Monday open for underlyings.
# - yfinance — weekend BTC, ES futures, sector ETF baselines.
#
# **Caveat:** only ~2 months of funding history at time of test. Statistical power limited.
#
# **Output:** regression table + $(\delta, \Delta R^2)$ plot → `reports/v3_funding_signal.md`.

# %%
from soothsayer.config import REPORTS
from soothsayer.universe import ALL_XSTOCKS

# TODO: implement after kraken_perp + yfinance_eod sources are built
